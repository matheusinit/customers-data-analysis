# %% [markdown]
# ### Ingestão

# %% [markdown]
# Importar os dados da planilha Excel usando a ferramenta pandas

# %%
import sys

sys.path.append('..')

from ingestion import load_data_from_excel_sheets

data = load_data_from_excel_sheets('../../data/dados_importacao.xlsx')

# %%
data.head()
# Out:
#      Nome/Razão Social Nome Fantasia        CPF/CNPJ Data Nasc.  \
# 0         Nicolas Melo           NaN  591.267.843-19 1982-03-16
# 1        Igor Silveira           NaN  102.694.758-85 1975-04-26
# 2      Henrique da Luz           NaN  782.531.904-41 1997-06-17
# 3    Valentina da Mota           NaN  865.902.374-92        NaT
# 4  Giovanna Cavalcanti           NaN  173.598.642-91 1964-11-30
#
#   Data Cadastro cliente     Celulares     Telefones  \
# 0            2023-01-02           NaN  5.581004e+12
# 1            2022-10-25  5.571677e+12           NaN
# 2            2022-10-11  5.511484e+12  5.531980e+12
# 3            2022-09-07  5.571144e+12  5.571606e+12
# 4            2023-02-13  5.541340e+12  5.531483e+12
#
#                        Emails                       Endereço Número  \
# 0             antonio65@da.br              Rua Trinta e Dois     82
# 1         larissa73@ramos.net  Avenida Vereador Pereira Neto    107
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Nome/Razão Social      1200 non-null   object
#  1   Nome Fantasia          1 non-null      object
#  2   CPF/CNPJ               1200 non-null   object
#  3   Data Nasc.             721 non-null    datetime64[ns]
#  4   Data Cadastro cliente  1200 non-null   datetime64[ns]
#  5   Celulares              1065 non-null   float64
#  6   Telefones              752 non-null    float64
#  7   Emails                 1167 non-null   object
#  8   Endereço               1198 non-null   object
#  9   Número                 1200 non-null   object
#  10  Complemento            1125 non-null   object
#  11  Bairro                 1200 non-null   object
#  12  CEP                    1199 non-null   object
#  13  Cidade                 1200 non-null   object
# ...
